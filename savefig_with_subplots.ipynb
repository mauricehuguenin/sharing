# %%
from matplotlib import gridspec
import matplotlib.pyplot as plt

# %%
save = '/g/data/e14/mv7494/HeatDist_figures/'
# initialise figure
fig = plt.figure(figsize=(8, 4.5),tight_layout=True,facecolor='w',edgecolor='k')
gs = gridspec.GridSpec(3, 2, width_ratios = [1,1])

ax1 = plt.subplot(gs[0:2,0])
ax1 = plt.subplot(gs[0,1])
ax1 = plt.subplot(gs[1,1])
ax1 = plt.subplot(gs[2,:])

# save figure
plt.savefig(save + 'test', dpi=300, facecolor='w',
            edgecolor='w', orientation='landscape',
            format=None, transparent=False, bbox_inches='tight', 
            pad_inches=0.1, metadata=None)
# --- end of script --------------------------------------------------------- #
