# %% [markdown]
# ### Issue with cosima cookbook since switching to new conda environment

# %%
# %%time
import cosima_cookbook as cc
import xarray as xr
from dask.distributed import Client
client = Client(n_workers=16)         # careful: do not run with 48 workers here as it will crash
client
# Out:
# CPU times: user 676 ms, sys: 512 ms, total: 1.19 s
# Wall time: 2.88 s
# <Client: 'tcp://127.0.0.1:42877' processes=16 threads=16, memory=68.72 GB>

# %%
# %%time
session = cc.database.create_session('/g/data/ik11/databases/cosima_master.db')
expt = '1deg_jra55v13_iaf_spinup1_B1'
temp = cc.querying.getvar(expt, 'temp', session, 'ocean.nc') - 273.15 # convert to °C
temp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.01/lib/python3.8/site-packages/cosima_cookbook/querying.py in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, **kwargs)
#     178     xr_kwargs.update(kwargs)
#     179
# --> 180     ds = xr.open_mfdataset(
#     181         (str(f.NCFile.ncfile_path) for f in ncfiles),
#     182         parallel=True,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.01/lib/python3.8/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, parallel, join, attrs_file, **kwargs)
#     910             paths = sorted(glob(_normalize_path(paths)))
#     911     else:
# --> 912         paths = [str(p) if isinstance(p, Path) else p for p in paths]
# ...

# %% [markdown]
# ### Trying to open file with usual xarray method

# %%
# %%time
temp = xr.open_mfdataset('/g/data/hh5/tmp/cosima/access-om2/1deg_jra55v13_iaf_spinup1_B1/output*/ocean/ocean.nc').temp
temp


# this is just too slow before it will eventually crash
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# <timed exec> in <module>
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.01/lib/python3.8/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, parallel, join, attrs_file, **kwargs)
# ...
